# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img_path = "/home/kz/Desktop/Research/NeuS2-official/Data/Ego4d/raw-data/upenn_0715_Piano_1_4/single_frame/first-frame/012960/aria01_rgb/012960.jpg"

# %%
original_img = cv2.imread(img_path, 1) # BGR
print(original_img.shape)
# Out:
# (1408, 1408, 3)

# %%
RGB_original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_original_img)
plt.show()
